# %% [markdown]
# <a href="https://colab.research.google.com/github/qxnqingxueng/text-based-music-playlist/blob/main/text_based_music_playlist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Program scenario**

# %% [markdown]
# In today's interconnected world, music holds a special place in our daily lives and able to manage the playlists efficiently is vital for music enthusiasts. To address this need, we are developing a fully text-based real life application in C++ that offers a comprehensive set of features for managing a song playlist. A program is needed to provide users with a perfect and intuitive interface to organize and display their music collection effectively. In a nutshell, an music app could cater to different individuals who love music and want to organize their playlists.
#
# We will discuss the essence of use cases and scenarios and explore the significance of scenario could be faced by users.

# %% [markdown]
# ### **First Scenario: User selects Next Song or Previous Song**
#
#  We begin by identifying a fundamental use case: "User selects Next Song or Previous Song". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the music app.
#
#  * **Scenario 1: User selects next song**
#
#   User selects next song from the menu and the system plays the next song in the playlist.
#
#  * **Scenario 2: User selects previous song**
#
#   User selects previous song from the menu and the system plays the previous song in the playlist.
#
#  * **Scenario 3: No next song available**
#
#   User selects next song but already reached the end of the playlist. The system communicates the unavailability of choosing next song so need to select options again.
#
#  * **Scenario 4: No previous song available**
#
#   User selects previous song when the song is at the beginning of the playlist and the system communicates the unavailability of choosing previous song so need to select options again.

# %% [markdown]
# ### **Second Scenario: User Edits Current Song or Deletes Current Song**
#
# Our team begins by identifying a fundamental use case: "User Edits Current Song or Deletes Current Song". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the music app.
#
# * **Scenario 1: User edits current song**
#
#   User edits current song from the menu, edit the details of the current song such as song name, song length, singer and genre. The system updates playlist.
#
# * **Scenario 2: User deletes current song**
#
#   User deletes current song from the menu and trigger the system to remove the current song from the playlist.
#
# * **Scenario 3: Edits current song by entering wrong details of the song**
#
#   In this scenario, the system communicates the unavailability of details of the song such as song name, song length, singer and genre to the user, who then decides to enter the data again.
#
# * **Scenario 4: All songs deleted**
#
#   User deletes current song multiple times until all songs are removed from the playlist. The system approve the deletion of each song until the playlist is empty.

# %% [markdown]
# ### **Third Scenario: User searches for a Song**
#
# Our team begins by identifying a fundamental use case: "User searches for a Song". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the music app.
#
# * **Scenario 1: Song is found in the playlist**
#
#   User searches for a song from the menu and enter the song name in the playlist. The system match the user input with the song in the playlist.
#
# * **Scenario 2: Song is not found in the playlist**
#
#   In this scenario, system communicates the unavailability of the song to the user, who then decide to select the options from the menu again.

# %% [markdown]
# ### **Fourth Scenario: User selects Song Recommendation by Genre**
#
# The team begins by identifying a fundamental use case: "User selects Song Recommendation by Genre”. This use case encapsulates the primary interaction between the user and the system, representing the core functionality of the music app.
#
# * **Scenario 1: User selects a genre with available recommendations**
#
#   User chooses song recommendation by genre from the menu and enters a genre. The system match the user input with the genre in the playlist.
#
# * **Scenario 2: User selects a genre with no available recommendations**
#
#   In this scenario, system communicates the unavailability of genre to the user, who then decide to select the options from the menu again.

# %% [markdown]
# ### **Fifth Scenario: User adds Song**
#
# We begin by identifying a fundamental use case: "User adds Song". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the music app.
#
# * **Scenario 1: User adds a new song**
#
#   User adds song from the menu and provides the details such as song name, song length, singer and genre. The system will then updates the playlist.
#
# * **Scenario 2: Add new song by entering wrong details of the song**
#
#   In this scenario, the system communicates the unavailability of details of the song such as song name, song length, singer and genre to the user, who then decides to enter the data again.
#
# * **Scenario 3: Duplicate song added**
#
#   In this scenario, the system communicates the unavailability of adding details of the song such as song name, song length, singer and genre due to matched song in the playlist, who then decide to select the options from the menu again.

# %% [markdown]
# ### **Sixth Scenario: User displays All Songs or shuffles Songs**
#
# We begin by identifying a fundamental use case: "User displays All Songs or shuffles Songs". This use case encapsulates the primary interaction between user and the system, representing the core functionality of the music app.
#
# * **Scenario 1: User displays all songs**
#
#   User display all songs from the menu. The system lists all the songs from the playlist.
#
# * **Scenario 2: User shuffles songs**
#
#   User shuffles songs from the menu. The system randomizes the order of songs in the playlist.
#
# * **Scenario 3: No display songs**
#
#   In this scenario, the system communicates the unavailability of displaying the song to the user due to no songs in the playlist and user need to select the options from the menu again.
#
# * **Scenario 4: No shuffle songs**
#
#   In this scenario, the system communicates the unavailability of shuffling the song to the user due to no songs in the playlist and user need to select the options from the menu again.

# %% [markdown]
# # **Description of the program requirements**

# %% [markdown]
# We need to conduct research and analysis before designing the system to understand the current system, recognize user expectations and requirements, and identify the steps necessary for developing our system.
#
# **Program requirement**
#
# According to the program scenario, the program requirements of this system are:
#
# 1. User able to select next song or previous song.
# 2. Uesr able to edit current song or delete current song.
# 3. User able to search for a song.
# 4. User able to select song recommendation by genre.
# 5. User able to add song.
# 6. User able to display all songs or shuffles songs.
#
# **System Requirement**
#
# Based on the program requirements, system requirements were defined in order to develop music app for music enthusiasts. We will show the key features and its description.

# %% [markdown]
# **Features and description:**
#
# 1. Initialize song playlist: Initialize the song playlist by reading songs from a file.
#
# 2. Handle empty playlist: Display a message to show no songs were found.
#
# 3. Current playing song: Display information about the currently playing song, including its name, singer, genre and length.
#
# 4. Song playlist menu: Display a menu with 10 options: Next Song, Previous Song, Edit Current Song, Delete Current Song, Search for a Song, Song Song Recommendation By Genre, Add Songs, Display All Songs, Shuffle Songs and Exit.
#
# 5. Input validation: Validates user input to ensure it falls within a specified range and is of the correct data type.
#
# 6. Play next song: Play the next song in the playlist if there is a next song available.
#
# 7. Play previous song: Play the previous song in the playlist if there is a previous song available.
#
# 8. Validate input string: Validates a string input to ensure it meets specific criteria such as not being empty and having the first character of each word as a capital letter or a digit.
#
# 9. Validate song length: Validates a string representing the length of a song to ensure it preform in a specific format (mm:ss).
#
# 10. Edit current song: Edits the details of the currently playing song in the playlist with the provided new song name, length, singer and genre.
#
# 11. Search song by Genre: Searches for songs with a genre in the playlist and displays the matching genre recommended songs.
#
# 12. Add song to playlist: Adds a new song to the playlist by entering the details such as song name, singer, song length and genre.
#
# 13. Display all songs: Displays all songs in the playlist along with the details such as song name, singer, genre and length.
#
# 14. Shuffle songs: Shuffles the songs in the playlist to randomize their order.
#
# 15. Exit confirmation: Display a message to prompt the user to confirm their intention to exit the program.
#
# 16. Delete current song: Delete the current playing song if there is song in the playlist yet.
#
# 17. Search for a song: Searches the song you want to find and the song will play it automatically.

# %% [markdown]
# **Requirement Validation**
#
# After analysing the current system and also program requirement, the system requirements were defined and each of this feature get visualize with a wireframe view and tabulated in above. All the requirements were then validated by user. Detailed system design will only start when the users verified that all their requirements on music app.

# %% [markdown]
# # **The problem your program is trying to solve using object-oriented programming**

# %% [markdown]
# **Our music app allows music enthusiasts to organize and display their music collection effectively.**
#
#
# 1. Playlist contains nodes which are the components of doubly linked list, containing the info and details of a song like song name, singer, length and genre.
#
# 2. Meanwhile node also has 2 pointers which are prev and next which hold the addresses of the previous and following songs, respectively as it is a doubly linked list. This can help the user to navigate through the playlist in both ways, forward and backward.
#
# 3. A playlist facilitates sorting and shuffling the songs.
#
# 4. A SongPlaylist is a derived class from its base class Playlist and contains more specific functions for users to manipulate with the playlist.
#
# 5. SongPlaylist can read and write song information to and from a text file, song.txt, which keeps record of those songs.
#
# 6. It also allows users to navigate through songs freely, having the flexibility to move to the next, previous songs by implementing functions based on the doubly linked list.
#
# 7. With SongPlaylist, users are able to add songs providing the song details in correct format while not giving the same or duplicated song details and they are able to delete the current song.
#
# 8. SongPlaylist allows searching song by song name in the correct format to play the desired song directly.
#
# 9. Additionally, the SongPlaylist includes a song recommendation feature based on genre.
#
# 10. Users can also change song information in the correct format and manage nodes using the SongPlaylist.
#
# 11. SongPlaylist can sort the playlist before saving to song.txt.

# %% [markdown]
# # **Analysis of the problem**

# %% [markdown]
# The first form of music listening came to our ears with live music. The music was not considered organized like we might call the music we listen to today. In the pre-digital era, music had to be purchased as physical media such as CDs and vinyl records  which required to visit a store and perhaps people would face challenges like specific album or song was not in stock and rural areas might not have the music stores. Buying albums and singles on vinyl or CDs could be expensive. After purchasing, we need some space to store records, tapes and CDs which take up considerable room in a home and not easily portable. Thus, the music app aims to ease people by providing a comfortable experience while effectively showcasing our powerful tool of our music app.

# %% [markdown]
# ## **Input**
#
# 1. **Song playlist menu**
#
#   We have provided a menu to allow users to choose their preferences based on the options which are Next Song, Previous Song, Edit Current Song, Delete Current Song,  Search for a Song, Song Recommendation By Genre, Add Songs, Display All Songs, Shuffle Songs and Exit. Users can interact with the system through menu and make selections.
#
# 2. **Select next song**
#
#   We have allowed users to select next song.
#
# 3. **Select previous song**
#
#   We have allowed users to select previous song.
#
# 4. **Edit current song**
#
#   We have provided users to edit current song by entering new song name, song length, singer and genre.
#
# 5. **Delete current song**
#
#   We have enable users to delete current song if they do not want that current playing song.
#
# 6. **Search for a song**
#
#   We have enable users to search for a song by entering the song name.
#
# 7. **Select song recommendation by genre**
#
#   We have allowed users to select song that recommended by genre by entering the genre.
#
# 8. **Add songs**
#
#   We have provided users to add song by entering new song name, song length, singer and genre.
#
# 9. **Display all songs**
#
#   We have allowed users to display all songs.
#
# 10. **Shuffle songs**
#
#   We have enable users to shuffle songs.
#
# 11. **Exit the song playlist menu**
#
#   We have allowed users exit the program at anytime.

# %% [markdown]
# ## **Process**
#
# 1. **Song playlist menu**
#
#   The program will use the user's input to direct them to the corresponding user interface and functionalities that tailored to their chosen. Users can interact with the system through menu and make selections again and again.
#
# 2. **Select next song**
#
#   The program will move to the next song and able to move until the last song in the playlist. Users can listen to the next song until the song reached end of the playlist.
#
# 3. **Select previous song**
#
#   The program will move to the previous song and able to move to the first song in the playlist. Users can listen to the previous song except the song is at the beginning of the playlist.
#
# 4. **Edit current song**
#
#   The program will use the user's input and change the details of the current song inside input file such as song name, song length, singer and genre. The first character for each word in song name and singer must be a capital letter otherwise user need to enter again. The format of the song length must be in (mm:ss) and cannot input must not be in digit and also minutes and seconds must be between 00 and 59 otherwise program will not accept the user's input.
#
# 5. **Delete current song**
#
#   The program will delete the current playing song inside the file and able to delete all songs inside the file as well.
#
# 6. **Search for a song**
#
#   The program will match the song name that entered by user with the song name that contained inside the file and play the song directly. If the song name does not match what we have on record, user may need to make selection again.
#
# 7. **Select song recommendation by genre**
#
#   The program will match the song genre that entered by user with the song genre that contained inside the file. If the song genre does not match what we have on record, user may need to make selection again.
#
# 8. **Add songs**
#
#   The program will use the user's input and add song inside input file such as song name, song length, singer and genre. The first character for each word in song name and singer must be a capital letter otherwise user need to enter again. The format of the song length must be in (mm:ss) and cannot input must not be in digit and also minutes and seconds must be between 00 and 59 otherwise program will not accept the user's input and prompt user to enter input again.
#
#
# 9. **Display all songs**
#
#   The program will show all songs that in the playlist unless there is no song in the playlist.
#
# 10. **Shuffle songs**
#
#   The program will randomize the song in the playlist unless there is no song in the playlist.
#
# 11. **Exit the song playlist menu**
#
#   The program will confirm with user again for exiting the program if the user try to exit and the songs will be written into the file.

# %% [markdown]
# ## **Output**
#
# 1. **Song playlist menu**
#
#   Display a song playlist that contain song name, singer, song length and genre and a menu for the user whether they want to choose Next Song, Previous Song, Edit Current Song, Delete Current Song, Search for a Song, Song Recommendation By Genre, Add Songs, Display All Songs, Shuffle Songs and Exit options.
#
# 2. **Select next song**
#
#   Display the next song in the playlist. If the song reached end of the playlist, it will display a message in which there is no next song anymore.
#
# 3. **Select previous song**
#
#   Display the previous song in the playlist. If the song is at the beginning of the playlist unless it will display a message in which there is no previous song.
#
# 4. **Edit current song**
#
#   Display a message in which succesfully edited the current song and still play the current song unless it will display a mesasge in which there is no current song to edit. If enter the wrong input, the program will prompt user to enter input again.
#
# 5. **Delete current song**
#
#   Display a message in which succesfully delete the current song unless it will display a message in which no song can be deleted anymore.
#
# 6. **Search for a song**
#
#   Display a message whether song name is found in the playlist or not.
#
# 7. **Select song recommendation by genre**
#
#   Display the preferred genre playlist for user to review.
#
# 8. **Add songs**
#
#   Display a message in which succesfully added the current song. If enter the wrong input, the program will prompt user to enter input again.
#
# 9. **Display all songs**
#
#   Display song name, singer, genre and song length unless display a message in which there is no song in the playlist.
#
# 10. **Shuffle songs**
#
#   Display song name, singer, genre and song length after shuffling unless display a message in which no song in the playlist to shuffle.
#
# 11. **Exit the song playlist menu**
#
#   Display a message for exit confirmation and the song written into the file.

# %% [markdown]
# # **How to run your program**

# %%
# %%writefile song.txt
# Song Name	Author	Song Length	Genre
# Memories	Maroon 5	03:09	Pop
# Old Town Road	Lil Nas X	02:37	Country
# Sunflower	Post Malone	02:38	Rap
# Bad Guy	Billie Eilish	03:14	Alternative
# Circles	Post Malone	03:35	Rap
# Havana	Camila Cabello	03:37	Pop
# Sicko Mode	Travis Scott	05:12	Rap
# God's Plan	Drake	03:19	Rap
# Perfect	Ed Sheeran	04:23	Pop
# Girls Like You	Maroon 5	03:55	Pop
# Senorita	Shawn Mendes	03:11	Pop
# Lovely	Billie Eilish	03:21	Alternative
# Without Me	Halsey	03:21	Pop
# Faded	Alan Walker	03:32	Electronic
# Lucid Dreams	Juice WRLD	03:59	Rap
# Out:
# Overwriting song.txt

# %%
# %%writefile playlist.h
# #ifndef PLAYLIST_H
# #define PLAYLIST_H
#
# #include <iostream>
# #include <string>
# using namespace std;
#
# // Forward declaration of SongPlaylist class
# template <typename T>
# class SongPlaylist;
#
# // Forward declaration of the function template
# template <typename T>
# void shuffleSongs(SongPlaylist<T>&);
#
# template <typename T>
# class Playlist {
#     protected:
#         struct Node {
#             T songName, singer, songLength, genre;
#             Node* prev;
#             Node* next;
#             Node(T name, T singer, T length, T genre)
#                 : songName(name), singer(singer), songLength(length), genre(genre), prev(nullptr), next(nullptr) {}
#         };
#         Node* head;
#         Node* tail;
#         Node* current;
#         bool isSorted;
#     public:
#         Playlist() : head(nullptr), tail(nullptr), current(nullptr), isSorted(true) {}
#         ~Playlist() {
#             while (head) {
#                 Node* temp = head;
#                 head = head->next;
#                 delete temp;
#             }
#         }
#         virtual void sortSongs() = 0;
#         friend void shuffleSongs<>(SongPlaylist<T>&);
# };
#
# #endif
# Out:
# Overwriting playlist.h

# %%
# %%writefile songplaylist.h
# #ifndef SONGPLAYLIST_H
# #define SONGPLAYLIST_H
#
# #include <string>
# #include "playlist.h"
# using namespace std;
#
# template <typename T>
# class SongPlaylist : public Playlist<T> {
# public:
#     // Constructor
#     SongPlaylist();
#     // Destructor
#     ~SongPlaylist();
#     // Function prototypes
#     void initializeList(const T&);
#     void addSong(const T&, const T&, const T&, const T&);
#     T tolower(const T&);
#     void nextSong();
#     void prevSong();
#     void writeToFile(const T&) const;
#     void destructList();
#     void sortSongs() override;
#     void displayCurrentSong() const;
#     void displayAllSongs() const;
#     typename Playlist<T>::Node* searchSong(const T&);
#     void searchByGenre(const T& genre) const;
#     void editCurrentSong(const T&, const T&, const T&, const T&);
#     void deleteNode(typename Playlist<T>::Node*);
#     typename Playlist<T>::Node* getCurrentPointer() const;
# };
#
# #endif
# Out:
# Overwriting songplaylist.h

# %%
# %%writefile songplaylist.cpp
# #include <iostream>
# #include <fstream>
# #include <string>
# #include "songplaylist.h"
# using namespace std;
#
# const int MAX_GENRES = 999;
#
# // Doubly Linked List class to manage the playlist
# template <typename T>
# SongPlaylist<T>::SongPlaylist() : Playlist<T>() {}
#
# template <typename T>
# SongPlaylist<T>::~SongPlaylist() {}
#
# template <typename T>
# void SongPlaylist<T> :: initializeList(const T& filename) {
#     ifstream file(filename);
#     if (!file) {
#         throw filename;
#         return;
#     }
#     int i = 0;
#     string header, line;
#     getline(file, header);
#     while (getline(file, line)) {
#         size_t pos1 = line.find('\t');
#         size_t pos2 = line.find('\t', pos1 + 1);
#         size_t pos3 = line.find('\t', pos2 + 1);
#         if (pos1 != string::npos && pos2 != string::npos && pos3 != string::npos) {
#             string songName = line.substr(0, pos1);
#             string singer = line.substr(pos1 + 1, pos2 - pos1 - 1);
#             string songLength = line.substr(pos2 + 1, pos3 - pos2 - 1);
#             string genre = line.substr(pos3 + 1);
#             addSong(songName, singer, songLength, genre);
#             i++;
#         }
#     }
#     file.close();
#     cout << i << " songs loaded and sorted from file: " << filename << "\n";
#     this->current = this->head;
#     if(i == 0){
#         cout << "No songs found.\n";
#     }
# }
#
# // Lowercasing so it can compare and sort when adding songs
# template <typename T>
# T SongPlaylist<T>::tolower(const T& songName) {
#     T lowerStr = songName;
#     for (int i = 0; i < lowerStr.length(); ++i) {
#         if(lowerStr[i] >= 'A' && lowerStr[i] <= 'Z'){
#             lowerStr[i] += 32; // convert to lowercase
#         }
#     }
#     return lowerStr;
# }
#
# // Add a song to the playlist
# template <typename T>
# void SongPlaylist<T>::addSong(const T& songName, const T& singer, const T& songLength, const T& genre) {
#     typename Playlist<T>::Node* newNode = new typename Playlist<T>::Node(songName, singer, songLength, genre);
#     typename Playlist<T>::Node* temp = this->head;
#     typename Playlist<T>::Node* prev = nullptr;
#
#     if (!this->head) {
#         this->head = this->tail = newNode;
#     } else {
#         while(temp){
#             if(temp->songName == songName && temp->singer == singer){
#                 cout << "Song already exists in the playlist.\n";
#                 return;
#             }
#             temp = temp->next;
#         }
#         // Ordered insertion, insert by song name A-Z
#         temp = this->head;
#         while (temp && (tolower(temp->songName) < tolower(songName))) {
#             prev = temp;
#             temp = temp->next;
#         }
#         if (!temp || !this->isSorted) {
#             // Append to the end of the list
#             // if the song name is the last
#             this->tail->next = newNode;
#             newNode->prev = this->tail;
#             this->tail = newNode;
#         }
#         else if (temp == this->head) {
#             // Insert at the beginning of the list
#             newNode->next = this->head;
#             this->head->prev = newNode;
#             this->head = newNode;
#         }
#         else {
#             // Insert in the middle of the list
#             newNode->next = temp;
#             newNode->prev = prev;
#             prev->next = newNode;
#             temp->prev = newNode;
#         }
#     }
#     cout << songName << " " << singer << " " << genre << " (" << songLength << " mins) added to the playlist.\n";
# }
#
# template <typename T>
# void SongPlaylist<T>::nextSong() {
#     if (!this->current || !this->current->next) {
#         cout << "No next song.\n";
#         return;
#     }
#     this->current = this->current->next;
#     cout << "Playing " << this->current->songName << " " << this->current->singer << " " << this->current->genre << " (" << this->current->songLength << " mins)\n";
# }
#
# // Move to the previous song
# template <typename T>
# void SongPlaylist<T>::prevSong() {
#     if (!this->current || !this->current->prev) {
#         cout << "No previous song.\n";
#         return;
#     }
#     this->current = this->current->prev;
#     cout << "Playing " << this->current->songName << " " << this->current->singer << " " << this->current->genre << " (" << this->current->songLength << " mins)\n";
# }
#
# template <typename T>
# void SongPlaylist<T>::writeToFile(const T& filename) const {
#     ofstream file(filename);
#     if (!file) {
#         throw filename;
#         return;
#     }
#
#     file << "Song Name\tAuthor\tSong Length\tGenre\n";
#
#     typename Playlist<T>::Node* temp = this->head;
#     while (temp) {
#         file << temp->songName << '\t' << temp->singer << '\t' << temp->songLength << '\t' << temp->genre << '\n';
#         temp = temp->next;
#     }
#
#     file.close();
#     cout << "Playlist written to file: " << filename << "\n";
# }
#
# template <typename T>
# void SongPlaylist<T>::sortSongs(){
#     typename Playlist<T>::Node* temp = this->head;
#     while (temp) {
#         typename Playlist<T>::Node* min = temp;
#         typename Playlist<T>::Node* temp2 = temp->next;
#         while (temp2) {
#             if (tolower(temp2->songName) < tolower(min->songName)) {
#                 min = temp2;
#             }
#             temp2 = temp2->next;
#         }
#         if (min != temp) {
#             T tempName = temp->songName;
#             T tempSinger = temp->singer;
#             T tempLength = temp->songLength;
#             T tempGenre = temp->genre;
#             temp->songName = min->songName;
#             temp->singer = min->singer;
#             temp->songLength = min->songLength;
#             temp->genre = min->genre;
#             min->songName = tempName;
#             min->singer = tempSinger;
#             min->songLength = tempLength;
#             min->genre = tempGenre;
#         }
#         temp = temp->next;
#     }
# }
#
# template <typename T>
# void SongPlaylist<T>::destructList() {
#     try {
#         writeToFile("song.txt");
#     } catch (string filename) {
#         cout << "ERROR: Cannot write to file " << filename << endl;
#     }
#     typename Playlist<T>::Node* temp = this->head;
#     while (temp) {
#         typename Playlist<T>::Node* next = temp->next;
#         delete temp;
#         temp = next;
#     }
#     this->head = this->tail = this->current = nullptr;
#     cout << "Playlist destructed.\n";
# }
#
# // Display the current song
# template <typename T>
# void SongPlaylist<T>::displayCurrentSong() const {
#     if (!this->current) {
#         cout << "\nNo song is currently playing.\n";
#         return;
#     }
#     cout << "\n======================= Currently Playing =======================\n";
#     cout << this->current->songName << " " << this->current->singer << " " << this->current->genre << " (" << this->current->songLength << " mins)\n";
#     cout << "=================================================================\n";
# }
#
# template <typename T>
# void SongPlaylist<T>::displayAllSongs() const {
#     typename Playlist<T>::Node* temp = this->head;
#     int count = 1;
#     cout << "\n======================= Playlist =======================\n";
#     while (temp) {
#         cout << count << ". " << temp->songName << " " << temp->singer << " " << temp->genre << " (" << temp->songLength << " mins)\n";
#         temp = temp->next;
#         count++;
#     }
#     if(count == 1){
#         cout << "No songs in the playlist.\n";
#     }
#     cout << "=======================================================\n";
# }
#
# template <typename T>
# typename Playlist<T>::Node* SongPlaylist<T>::searchSong(const T& songName) {
#     typename Playlist<T>::Node* temp = this->head;
#     while (temp) {
#         if (temp->songName == songName) {
#             cout << songName << " found in the playlist.\n";
#             this->current = temp; // after song found, assign it as currently playing
#             return temp;
#         }
#         temp = temp->next;
#     }
#     cout << songName << " not found in the playlist.\n";
#     return nullptr;
# }
#
# template <typename T>
# void SongPlaylist<T>::searchByGenre(const T& genre) const {
#     typename Playlist<T>::Node* temp = this->head;
#     bool found = false;
#     cout << "\n Your personal " << genre << " playlist\n=================================================================\n";
#     while (temp) {
#         if (temp->genre == genre) {
#             cout << temp->songName << " " << temp->singer << " " << temp->genre << " (" << temp->songLength << " mins)\n";
#             found = true;
#         }
#         temp = temp->next;
#     }
#     if (!found) {
#         cout << "No songs found in the genre " << genre << ".\n";
#     }
#     cout << "=================================================================\n";
# }
#
# // Edit the content of the current node
# template <typename T>
# void SongPlaylist<T>::editCurrentSong(const T& newSongName, const T& newSongLength, const T& newSinger, const T& newGenre) {
#     typename Playlist<T>::Node* temp = this->head;
#     while(temp){
#         // added temp != current to ignore/skip the current same song name, user might wants to edit the current song's details
#         if(temp->songName == newSongName && temp->singer == newSinger && temp != this->current){
#             cout << "Song already exists in the playlist.\n";
#             return;
#         }
#         temp = temp->next;
#     }
#     if (this->current) {
#         this->current->songName = newSongName;
#         this->current->singer = newSinger;
#         this->current->songLength = newSongLength;
#         this->current->genre = newGenre;
#         cout << "\nCurrent song edited to: " << newSongName << " " << newSinger << " " << newGenre << " (" << newSongLength << " mins)\n";
#     }
#     else {
#         cout << "No current song to edit.\n";
#     }
# }
#
# template <typename T>
# void SongPlaylist<T>::deleteNode(typename Playlist<T>::Node* node) {
#     if (!node) return;
#
#     if (node == this->head) {
#         this->head = node->next;
#         if (this->head) this->head->prev = nullptr;
#     }
#     else {
#         node->prev->next = node->next;
#     }
#
#     if (node == this->tail) {
#         this->tail = node->prev;
#         if (this->tail) this->tail->next = nullptr;
#     }
#     else {
#         node->next->prev = node->prev;
#     }
#
#     if (node == this->current) {
#         this->current = node->next ? node->next : node->prev;
#     }
#
#     delete node;
#
#     cout << "This song is deleted from the playlist.\n";
# }
#
# template <typename T>
# typename Playlist<T>::Node* SongPlaylist<T>::getCurrentPointer() const{
#     if (!this->current) {
#         string noCurrent = "No current song! ";
#         throw noCurrent;
#     }
#     return this->current;
# }
#
# template class SongPlaylist<string>; // instantiating the class
# Out:
# Overwriting songplaylist.cpp

# %%
# %%writefile main.cpp
# #include <iostream>
# #include "playlist.h"
# #include "songplaylist.h"
# using namespace std;
#
# const int MAX_STREAM_SIZE = 32767;
# void displayMenu();
# bool exitConfirmation();
# bool validateInput(int,int,int);
# bool validateInputPureDigit(const string&);
# bool validateInputString(const string&);
# bool validateSongLength(const string&);
#
# int main() {
#     SongPlaylist<string> myPlaylist;
#     bool running = true;
#
#     try {
#         myPlaylist.initializeList("song.txt");
#     } catch (string filename) {
#         cout << "ERROR: Cannot open file " << filename << endl;
#         running = false;
#     }
#
#     while (running) {
#
#         myPlaylist.displayCurrentSong();
#
#         int choice;
#         do {
#             displayMenu();
#             cin >> choice;
#         } while (validateInput(choice,1,10));
#
#         cin.ignore(MAX_STREAM_SIZE, '\n'); // Clear input buffer
#         string songName, genre,editSongName, editSongLength, editSinger, editGenre, newSongName, newSongLength, newSinger, newGenre;
#         switch (choice) {
#         case 1:
#             myPlaylist.nextSong();
#             break;
#         case 2:
#             myPlaylist.prevSong();
#             break;
#         case 3:
#             do{
#                 cout << "Enter new song name: ";
#                 getline(cin, editSongName);
#             }while(validateInputString(editSongName));
#             do{
#                 cout << "Enter new song length: ";
#                 getline(cin, editSongLength);
#             }while(validateSongLength(editSongLength));
#             do{
#                 cout << "Enter new singer: ";
#                 getline(cin, editSinger);
#             }while(validateInputString(editSinger));
#             do{
#                 cout << "Enter new genre: ";
#                 getline(cin, editGenre);
#             }while(validateInputString(editGenre) || validateInputPureDigit(editGenre));
#             myPlaylist.editCurrentSong(editSongName, editSongLength, editSinger, editGenre);
#             break;
#
#         case 4:
#             try{
#                 myPlaylist.deleteNode(myPlaylist.searchSong(myPlaylist.getCurrentPointer()->songName));
#             }catch(string noCurrent){
#                 cout << noCurrent << "Nothing to delete.\n";
#             }
#             break;
#
#         case 5:
#             do{
#                 cout << "Enter song name to search: ";
#                 getline(cin, songName);
#             }while(validateInputString(songName));
#             myPlaylist.searchSong(songName);
#             break;
#
#         case 6:
#             do{
#                 cout << "What genre of music are you in the mood for right now?\n";
#                 cin >> genre;
#             }while(validateInputString(genre) || validateInputPureDigit(genre));
#             myPlaylist.searchByGenre(genre);
#             break;
#
#         case 7:
#             do{
#                 cout << "Enter new song name: ";
#                 getline(cin, newSongName);
#             }while(validateInputString(newSongName));
#             do{
#                 cout << "Enter new song length: ";
#                 getline(cin, newSongLength);
#             }while(validateSongLength(newSongLength));
#             do{
#                 cout << "Enter new singer: ";
#                 getline(cin, newSinger);
#             }while(validateInputString(newSinger));
#             do{
#                 cout << "Enter new genre: ";
#                 getline(cin, newGenre);
#             }while(validateInputString(newGenre) || validateInputPureDigit(newGenre));
#             myPlaylist.addSong(newSongName, newSinger, newSongLength, newGenre);
#             break;
#
#         case 8:
#             myPlaylist.displayAllSongs();
#             break;
#
#         case 9:
#             try {
#                 shuffleSongs<string>(myPlaylist);
#                 cout << "Playlist shuffled.\n";
#             } catch (string noShuffle) {
#                 cout << noShuffle;
#             }
#             myPlaylist.displayAllSongs();
#             break;
#
#         case 10:
#             if (exitConfirmation()) {
#                 running = false;
#                 myPlaylist.sortSongs(); // sort songs before rewriting to the file
#                 myPlaylist.destructList();
#                 cout << "Program ended.";
#             }
#             break;
#         default:
#             break;
#         }
#     }
#
#     return 0;
# }
#
#
# void displayMenu() {
#     cout << "\n======== Song Playlist Menu ========\n"
#          << "  1. Next Song\n"
#          << "  2. Previous Song\n"
#          << "  3. Edit Current Song\n"
#          << "  4. Delete Current Song\n"
#          << "  5. Search for a Song\n"
#          << "  6. Song Recommendation By Genre\n"
#          << "  7. Add Songs\n"
#          << "  8. Display All Songs\n"
#          << "  9. Shuffle Songs\n"
#          << "  10. Exit\n"
#          << "====================================\n"
#          << "Enter your choice: ";
# }
#
# bool exitConfirmation() {
#     string isExit;
#     cout << endl;
#     cout << "Press Y/y to exit program: ";
#     cin >> isExit;
#     cin.ignore(MAX_STREAM_SIZE, '\n');
#     if (isExit == "Y" || isExit == "y") {
#         return true;
#     }
#     return false;
# }
#
# bool validateInput(int userInput, int min, int max) {
#     if (!(cin.fail()) && userInput >= min && userInput <= max) {
#         return false;
#     } else {
#         cout << endl;
#         cout << "ERROR: Input must be from " << min << " to " << max << "." << endl;
#         cout << endl;
#         // since the input might be char for int type, so we need to clear the error flag
#         cin.clear();
#         // and clear any input buffer
#         cin.ignore(MAX_STREAM_SIZE, '\n');
#         return true;
#     }
# }
#
# bool validateInputPureDigit(const string& userInput) {
#     for (int i = 0; i < userInput.length(); i++) {
#         if (!isdigit(userInput[i])) {
#             // Not digit, return false to break while loop (correct input)
#             return false;
#         }
#     }
#     // All digits
#     cout << "ERROR: Input must not be all digits.\n";
#     return true;
# }
#
# bool validateInputString(const string& userInput) {
#     // Check if the string is empty
#     if (userInput.empty()) {
#         cout << "ERROR: Input cannot be empty.\n";
#         return true;
#     }
#     // Check if first char for each word is capital letter or digit
#     for(int i = 0; i < userInput.length(); i++) {
#         // first char for each word
#         if((i == 0 || userInput[i-1] == ' ') && !isdigit(userInput[i])){
#             // not capital letter?
#             if (!isupper(userInput[i])) {
#                 cout << "ERROR: First character for each word must be a capital letter.\n";
#                 return true;
#             }
#         }
#         if(i == userInput.length() - 1 && userInput[i] == ' '){
#             cout << "ERROR: There must be no space at the end.\n";
#             return true;
#         }
#     }
#     return false;
# }
#
# bool validateSongLength(const string& songLength) {
#     if (songLength.empty()) {
#         cout << "ERROR: Input cannot be empty.\n";
#         return true;
#     }
#     size_t colonPos = songLength.find(':');
#     if (colonPos == string::npos || colonPos == 0 || colonPos == songLength.length() - 1) {
#         // If there is no colon, or the colon is at the start or end of the string, the format is invalid
#         cout << "ERROR: Invalid format. Please enter the song length in the format mm:ss.\n";
#         return true;
#     }
#
#     for (int i = 0; i < songLength.length(); ++i) {
#         if (i != colonPos && !isdigit(songLength[i])) {
#             // If any character other than the colon is not a digit, the format is invalid
#             cout << "ERROR: Invalid format. Please enter the song length with DIGITS in the format mm:ss.\n";
#             return true;
#         }
#     }
#
#     string minutes, seconds;
#     // Extract minutes and seconds
#     for(int i = 0; i < songLength.length(); i++){
#         if(i < colonPos){
#             minutes += songLength[i];
#         }else if(i > colonPos){
#             seconds += songLength[i];
#         }
#     }
#
#     // Check if minutes and seconds are within valid range
#     if (minutes.length() != 2 || seconds.length() != 2 || minutes < "00" || minutes > "59" || seconds < "00" || seconds > "59") {
#         cout << "ERROR: Invalid time or format. Minutes and seconds must be between 00 and 59 in the format mm:ss.\n";
#         return true;
#     }
#
#     return false;
# }
#
# template <typename T>
# void shuffleSongs(SongPlaylist<T>& playlist) {
#     // get the size of the linked list
#     int size = 0;
#     for (typename Playlist<T>::Node* node = playlist.head; node != nullptr; node = node->next) {
#         size++;
#     }
#
#     if(size != 0){
#         // shuffle the linked list
#         for (typename Playlist<T>::Node* node = playlist.head; node != nullptr; node = node->next) {
#             // Get a random index from 0 to size - 1
#             int j = rand() % size;
#
#             // Traverse the linked list to find the song at index j
#             typename Playlist<T>::Node* song_j = playlist.head;
#             for (int k = 0; k < j; ++k) {
#                 song_j = song_j->next;
#             }
#
#             // Swap the songs
#             typename Playlist<T>::Node temp = {node->songName, node->singer, node->songLength, node->genre};
#             node->songName = song_j->songName;
#             node->singer = song_j->singer;
#             node->songLength = song_j->songLength;
#             node->genre = song_j->genre;
#             song_j->songName = temp.songName;
#             song_j->singer = temp.singer;
#             song_j->songLength = temp.songLength;
#             song_j->genre = temp.genre;
#         }
#     }else{
#         string noShuffle = "No songs to shuffle.\n";
#         throw noShuffle;
#     }
#
#     // Set the current song to the head of the list
#     playlist.current = playlist.head;
#
#     // Set the isSorted flag to false
#     playlist.isSorted = false;
# }
# Out:
# Overwriting main.cpp

# %% [markdown]
# **First Scenario: User selects Next Song or Previous Song**
#
# Scenario 1: User selects next song
#
# User selects next song from the menu and the system plays the next song in the playlist.
#
# Scenario 2: User selects previous song
#
# User selects previous song from the menu and the system plays the previous song in the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 3: No next song available
#
# User selects next song but already reached the end of the playlist. The system communicates the unavailability of choosing next song so need to select options again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 4: No previous song available
#
# User selects previous song when the song is at the beginning of the playlist and the system communicates the unavailability of choosing previous song so need to select options again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# **Second Scenario: User Edits Current Song or Deletes Current Song**
#
# Scenario 1: User edits current song
#
# User edits current song from the menu, edit the details of the current song such as song name, song length, singer and genre. The system updates playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 2: User deletes current song
#
# User deletes current song from the menu and trigger the system to remove the current song from the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# One In A Million Twice R&B (02:55 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 3: Edits current song by entering wrong details of the song
#
# In this scenario, the system communicates the unavailability of details of the song such as song name, song length, singer and genre to the user, who then decides to enter the data again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# One In A Million Twice R&B (02:55 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# 14 songs loaded and sorted from file: song.txt
#
# ...

# %% [markdown]
# Scenario 4: All songs deleted
#
# User deletes current song multiple times until all songs are removed from the playlist. The system approve the deletion of each song until the playlist is empty.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Blank Space Taylor Swift Pop (04:33 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# One In A Million Twice R&B (02:55 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# 14 songs loaded and sorted from file: song.txt
#
# ...

# %% [markdown]
# **Third Scenario: User searches for a Song**
#
# Scenario 1: Song is found in the playlist
#
# User searches for a song from the menu and enter the song name in the playlist. The system match the user input with the song in the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 2: Song is not found in the playlist
#
# In this scenario, system communicates the unavailability of the song to the user, who then decide to select the options from the menu again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# **Fourth Scenario: User selects Song Recommendation by Genre**
#
# Scenario 1: User selects a genre with available recommendations
#
# User chooses song recommendation by genre from the menu and enters a genre. The system match the user input with the genre in the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# **Scenario 2: User selects a genre with no available recommendations**
#
# In this scenario, system communicates the unavailability of genre to the user, who then decide to select the options from the menu again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# **Fifth Scenario: User adds Song**
#
# Scenario 1: User adds a new song
#
# User adds song from the menu and provides the details such as song name, song length, singer and genre. The system will then updates the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Without Me Halsey Pop (03:21 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 2: Add new song by entering wrong details of the song
#
# In this scenario, the system communicates the unavailability of details of the song such as song name, song length, singer and genre to the user, who then decides to enter the data again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# Thinking Out Loud Ed Sheeran Soft Rock (04:57 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 3: Duplicate song added
#
# In this scenario, the system communicates the unavailability of adding details of the song such as song name, song length, singer and genre due to matched song in the playlist, who then decide to select the options from the menu again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Shake It Off Taylor Swift Pop (04:02 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# ...

# %% [markdown]
# **Sixth Scenario: User displays All Songs or shuffles Songs**
#
# Scenario 1: User displays all songs
#
# User display all songs from the menu. The system lists all the songs from the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Shake It Off Taylor Swift Pop (04:02 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 2: User shuffles songs
#
# User shuffles songs from the menu. The system randomizes the order of songs in the playlist.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Shake It Off Taylor Swift Pop (04:02 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 3: No display songs
#
# In this scenario, the system communicates the unavailability of displaying the song to the user due to no songs in the playlist and user need to select the options from the menu again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# Bad Guy Billie Eilish Alternative (03:14 mins) added to the playlist.
# Circles Post Malone Rap (03:35 mins) added to the playlist.
# Faded Alan Walker Electronic (03:32 mins) added to the playlist.
# Girls Like You Maroon 5 Pop (03:55 mins) added to the playlist.
# God's Plan Drake Rap (03:19 mins) added to the playlist.
# Havana Camila Cabello Pop (03:37 mins) added to the playlist.
# Lovely Billie Eilish Alternative (03:21 mins) added to the playlist.
# Lucid Dreams Juice WRLD Rap (03:59 mins) added to the playlist.
# Memories Maroon 5 Pop (03:09 mins) added to the playlist.
# Old Town Road Lil Nas X Country (02:37 mins) added to the playlist.
# Perfect Ed Sheeran Pop (04:23 mins) added to the playlist.
# Senorita Shawn Mendes Pop (03:11 mins) added to the playlist.
# Shake It Off Taylor Swift Pop (04:02 mins) added to the playlist.
# Sicko Mode Travis Scott Rap (05:12 mins) added to the playlist.
# Sunflower Post Malone Rap (02:38 mins) added to the playlist.
# ...

# %% [markdown]
# Scenario 4: No shuffle songs
#
# In this scenario, the system communicates the unavailability of shuffling the song to the user due to no songs in the playlist and user need to select the options from the menu again.

# %%
# %%shell
# g++ *.cpp -o main.exe
# ./main.exe
# Out:
# 0 songs loaded and sorted from file: song.txt
# No songs found.
#
# No song is currently playing.
#
# ======== Song Playlist Menu ========
#   1. Next Song
#   2. Previous Song
#   3. Edit Current Song
#   4. Delete Current Song
#   5. Search for a Song
#   6. Song Recommendation By Genre
#   7. Add Songs
#   8. Display All Songs
#   9. Shuffle Songs
#   10. Exit
# ...
# Enter your choice: 9
# No songs to shuffle.
#
# ======================= Playlist =======================
# No songs in the playlist.
# ...
#
# No song is currently playing.
#
# ======== Song Playlist Menu ========
#   1. Next Song
#   2. Previous Song
#   3. Edit Current Song
#   4. Delete Current Song
#   5. Search for a Song
#   6. Song Recommendation By Genre
#   7. Add Songs
#   8. Display All Songs
#   9. Shuffle Songs
#   10. Exit
# ...
# Enter your choice: 10
#
# Press Y/y to exit program: y
# Playlist written to file: song.txt
# Playlist destructed.
# Program ended.
